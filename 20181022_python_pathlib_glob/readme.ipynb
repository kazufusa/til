# %%
import os
from pathlib import Path

def find(p, ext):
    print(f"pattern: **/*.{ext}\nresults:")
    for f in p.glob(f"**/*.{ext}"):
        print(f.name)

if __name__ == '__main__':
    find(Path.home() / 'src', ['c', 'h'])
# Out:
# pattern: **/*.['c', 'h']
# results:
# config.h
# compat.h
# ansidecl.h
# utf8proc_data.c
# hashtab.c
# strndup.c
# mkstemps.c
# utf8proc.h
# hashtab.h
# utf8proc.c
# wordexp.c
# setenv.c
# test-graph.c
# header.h
# doc-gen.c
# blob.h
# types.h
# blame.h
# tig.h
# tree.h
# argv.h
# diff.h
# display.h
# draw.h
# request.h
# string.h
# map.h
# git.h
# repo.h
# help.h
# pager.h
# line.h
# graph.h
# watch.h
# prompt.h
# ui.h
# refdb.h
# main.h
# stash.h
# io.h
# status.h
# keys.h
# apps.h
# stage.h
# view.h
# grep.h
# options.h
# parse.h
# refs.h
# util.h
# search.h
# log.h
# view.c
# tig.c
# graph-v1.c
# builtin-config.c
# refdb.c
# log.c
# stage.c
# blob.c
# stash.c
# display.c
# search.c
# prompt.c
# argv.c
# graph.c
# tree.c
# request.c
# ui.c
# util.c
# repo.c
# string.c
# draw.c
# parse.c
# apps.c
# line.c
# status.c
# main.c
# graph-v2.c
# options.c
# watch.c
# diff.c
# grep.c
# map.c
# io.c
# types.c
# blame.c
# pager.c
# refs.c
# help.c
# keys.c
# mazeansi.c
# maze.c
# ...
