# %% [markdown]
# $$
# \begin{eqnarray}
# p(\boldsymbol X \mid \boldsymbol \mu, \boldsymbol \Lambda) &=&
#     \frac {\boldsymbol {| \Lambda |} ^{ \frac {N} {2} }} {(2\pi)^{ \frac {ND} {2} }}
#     \prod_{i=1}^N exp \left(
#         - \frac {1} {2}
#         \left( \boldsymbol x_i - \boldsymbol \mu \right)^{T}
#         \boldsymbol \Lambda
#         \left(\boldsymbol  x_i - \boldsymbol \mu
#     \right)
# \right)
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# \begin{eqnarray}
# p(\boldsymbol \mu, \boldsymbol \Lambda) &=& p(\boldsymbol \mu \mid \boldsymbol \Lambda)p(\boldsymbol \Lambda) \\
# &=&
#     \mathcal {N} \left(\boldsymbol \mu \mid \boldsymbol \mu_{0}, (\beta_{0} \boldsymbol \Lambda)^{-1} \right)
#     \mathcal {W} \left(\boldsymbol \Lambda \mid \nu_{0}, \boldsymbol W_{0} \right)
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# {\rm ln } \mathcal {W} \left(\bf \Lambda \mid \nu_{0}, \bf W_{0} \right) =
# \frac{\nu_{0} - D - 1} {2} {\rm ln } \left| \bf \Lambda \right|
# -\frac {1} {2} {\rm Tr} (\bf W_{0}^{-1}\bf \Lambda) + {\rm const}
# $$

# %% [markdown]
# $$
# \begin{eqnarray}
# {\rm ln} \, q^{\ast}_{\boldsymbol \mu} (\boldsymbol \mu) &=& \mathbb{E}_{\boldsymbol \Lambda} \left\lbrack
#     {\rm ln} \left(
#         p(\boldsymbol X \mid \boldsymbol \mu, \boldsymbol \Lambda)
#         p(\boldsymbol \mu \mid \boldsymbol \Lambda)p(\boldsymbol \Lambda)
#     \right)
# \right\rbrack \\
# &=& - \frac {1} {2} \mathbb{E}_{\boldsymbol \Lambda} \left\lbrack
#     \Sigma_{i=1}^{N} \left(
#         \left( \boldsymbol x_i - \boldsymbol \mu \right)^{\rm T}
#         \boldsymbol \Lambda
#         \left(\boldsymbol  x_i - \boldsymbol \mu \right)
#     \right)
#     +
#         \left( \boldsymbol \mu - \boldsymbol \mu_{0} \right)^{\rm T}
#         \beta_{0}\boldsymbol \Lambda
#         \left(\boldsymbol \mu - \boldsymbol \mu_{0} \right)
# \right\rbrack + {\rm const } \\
# &=& - \frac {1} {2} \mathbb{E}_{\boldsymbol \Lambda} \left\lbrack
#     \boldsymbol \mu ^{\rm T} (N + \beta_{0}) \boldsymbol \Lambda \boldsymbol \mu
#     - \left(\Sigma_{i=1}^{N} \boldsymbol x_i + \beta_{0} \boldsymbol \mu_{0} \right)^{\rm T} \boldsymbol \Lambda \boldsymbol \mu
#     - \boldsymbol \mu ^{\rm T} \boldsymbol \Lambda \left( \Sigma_{i=1}^{N} \boldsymbol x_i + \beta_{0} \boldsymbol \mu_{0} \right)
# \right\rbrack + {\rm const } \\
# &=& - \frac {1} {2} \left(
#         \boldsymbol \mu ^{\rm T} (N + \beta_{0})
#         \mathbb{E} \left\lbrack \boldsymbol \Lambda \right\rbrack
#         \boldsymbol \mu
#         - \left(\Sigma_{i=1}^{N} \boldsymbol x_i + \beta_{0} \boldsymbol \mu_{0} \right)^{\rm T}
#         \mathbb{E} \left\lbrack \boldsymbol \Lambda \right\rbrack
#         \boldsymbol \mu
#         - \boldsymbol \mu ^{\rm T}
#         \mathbb{E} \left\lbrack \boldsymbol \Lambda \right\rbrack
#         \left( \Sigma_{i=1}^{N} \boldsymbol x_i + \beta_{0} \boldsymbol \mu_{0} \right)
#      \right)
#      + {\rm const } \\
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# q^{\ast}_{\boldsymbol \mu}(\boldsymbol \mu) = \mathcal {N} \left(\boldsymbol \mu \mid \boldsymbol \mu_{N}, \boldsymbol \Lambda_{N} ^{-1} \right) \\
# \boldsymbol \mu_{N} = \frac {\Sigma_{i=1}^{N} \boldsymbol x_i + \beta_{0} \boldsymbol \mu_{0}} {N + \beta_{0}}\\
# \boldsymbol \Lambda_{N} = (N + \beta_{0}) \mathbb {E} \left\lbrack\boldsymbol \Lambda \right\rbrack
# $$

# %% [markdown]
# $$
# \begin{eqnarray}
# {\rm ln}\, q^{\ast}_{\boldsymbol \Lambda} (\boldsymbol \Lambda) &=& \mathbb{E}_{\boldsymbol \mu} \left\lbrack
#     {\rm ln} \left(
#         p(\boldsymbol X \mid \boldsymbol \mu, \boldsymbol \Lambda)
#         p(\boldsymbol \mu \mid \boldsymbol \Lambda)p(\boldsymbol \Lambda)
#     \right)
# \right\rbrack \\
# &=& \mathbb{E}_{\boldsymbol \mu} \left\lbrack
#     \frac{N} {2} {\rm ln} \left| \boldsymbol \Lambda \right|
#     - \frac {1} {2} \Sigma_{i=1}^{n}
#         \left(\textbf x_{i} - \boldsymbol \mu\right)^{\rm T}
#         \boldsymbol\Lambda
#         \left(\textbf x_{i} - \boldsymbol \mu\right)
#     + \frac{1} {2} {\rm ln} \left| \boldsymbol \Lambda \right|
#     - \frac {1} {2}
#         \left(\boldsymbol \mu - \boldsymbol \mu_{0}\right)^{\rm T}
#         \beta_{0}\boldsymbol\Lambda
#         \left(\boldsymbol \mu - \boldsymbol \mu_{0}\right)
#     + \frac{\nu_{0} - D - 1} {2} {\rm ln } \left| \bf \Lambda \right|
#     -\frac {1} {2} {\rm Tr} (\bf W_{0}^{-1}\bf \Lambda)
# \right\rbrack + {\rm const } \\
# &=& \mathbb{E}_{\boldsymbol \mu} \left\lbrack
#     \frac{N + \nu_{0} -D} {2} {\rm ln} \left| \boldsymbol \Lambda \right|
#     - \frac {1} {2} {\rm Tr} \left\lbrace
#         \boldsymbol \Lambda
#         \left(
#             \Sigma_{i=1}^{n}
#                 \left(\textbf x_{i} - \boldsymbol \mu\right)
#                 \left(\textbf x_{i} - \boldsymbol \mu\right)^{\rm T}
#             + \beta_{0}
#                 \left(\boldsymbol \mu - \boldsymbol \mu_{0}\right)
#                 \left(\boldsymbol \mu - \boldsymbol \mu_{0}\right)^{\rm T}
#             + \bf W_{0}^{-1}
#         \right)
#     \right\rbrace
# \right\rbrack + {\rm const } \\
# &=&
#     \frac{N + \nu_{0} -D} {2} {\rm ln} \left| \boldsymbol \Lambda \right|
#     - \mathbb{E}_{\boldsymbol \mu} \left\lbrack
#         \frac {1} {2} {\rm Tr} \left\lbrace
#         \boldsymbol \Lambda
#         \left(
#             \Sigma_{i=1}^{n} \textbf{x}_i \textbf{x}_i^{\rm T}
#             - \Sigma_{i=1}^{n} \textbf{x}_i \boldsymbol \mu^{\rm T}
#             -  \boldsymbol\mu \Sigma_{i=1}^{n} \textbf{x}_i^{\rm T}
#             + N\boldsymbol{\mu \mu}^{\rm T}
#             + \beta_{0} \boldsymbol \mu \boldsymbol \mu^{\rm T}
#             - \beta_{0} \boldsymbol \mu \boldsymbol \mu_0^{\rm T}
#             - \beta_{0} \boldsymbol \mu_0 \boldsymbol \mu^{\rm T}
#             + \beta_{0} \boldsymbol \mu_0 \boldsymbol \mu_0^{\rm T}
#             + {\bf W}_{0}^{-1}
#         \right)
#     \right\rbrace
# \right\rbrack + {\rm const } \\
# &=&
#     \frac{N + \nu_{0} -D} {2} {\rm ln} \left| \boldsymbol \Lambda \right|
#     - \frac {1} {2} {\rm Tr} \left\lbrace
#         \boldsymbol \Lambda
#         \left(
#             \left(N + \beta_0\right)\mathbb{E} \left\lbrack\boldsymbol{\mu \mu}^{\rm T} \right\rbrack
#             - \left(\Sigma_{i=1}^{n} \textbf{x}_i + \beta_0 \boldsymbol \mu_0\right)
#                 \mathbb{E} \left\lbrack \boldsymbol \mu \right\rbrack^{\rm T}
#             - \mathbb{E} \left\lbrack \boldsymbol \mu \right\rbrack
#                 \left(\Sigma_{i=1}^{n} \textbf{x}_i + \beta_0 \mu_0 \right)^{\rm T}
#             + \Sigma_{i=1}^{n} \textbf{x}_i \textbf{x}_i^{\rm T}
#             + \beta_{0} \boldsymbol \mu_0 \boldsymbol \mu_0^{\rm T}
#             + {\bf W}_{0}^{-1}
#         \right)
# \right\rbrace + {\rm const } \\
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# \nu_{N} = N + \nu_0 + 1 \\
# {\bf W}_{0}^{-1} =
#     \left(N + \beta_0\right)\mathbb{E} \left\lbrack\boldsymbol{\mu \mu}^{\rm T} \right\rbrack
#     - \left(\Sigma_{i=1}^{n} \textbf{x}_i + \beta_0 \boldsymbol \mu_0\right)
#         \mathbb{E} \left\lbrack \boldsymbol \mu \right\rbrack^{\rm T}
#     - \mathbb{E} \left\lbrack \boldsymbol \mu \right\rbrack
#         \left(\Sigma_{i=1}^{n} \textbf{x}_i + \beta_0 \mu_0 \right)^{\rm T}
#     + \Sigma_{i=1}^{n} \textbf{x}_i \textbf{x}_i^{\rm T}
#     + \beta_{0} \boldsymbol \mu_0 \boldsymbol \mu_0^{\rm T}
#     + {\bf W}_{0}^{-1}
# $$
#
# できた.
